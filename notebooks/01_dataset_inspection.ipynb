# %% [markdown]
# # 01 — Dataset Inspection\nThis notebook is the first analysis step. We inspect the two Kaggle datasets before cleaning or training anything.

# %%
from pathlib import Path\nimport pandas as pd\n\nROOT = Path.cwd().parent\njob_path = ROOT / 'data/raw/job_skill_set/all_job_post.csv'\nmatch_path = ROOT / 'data/raw/vocational_skill_job/Skill_Job_Matching_Dataset.csv'\n\njobs = pd.read_csv(job_path)\nmatch = pd.read_csv(match_path)

# %%
jobs.shape, match.shape

# %%
jobs.head()

# %%
match.head()

# %%
jobs.info()\nmatch.info()

# %%
print(jobs['category'].value_counts())\nprint('Unique job titles:', jobs['job_title'].nunique())\nprint(match['Job_Title'].value_counts())

# %% [markdown]
# ## Next\nWe will inspect the actual skill lists and determine how to normalize job skills into a common vocabulary.
